# %% [markdown]
# <img src = "https://www.bits-pilani.ac.in/Uploads/Campus/BITS_university_logo.gif">

# %% [markdown]
# <h1><center>Work Integrated Learning Programmes Division<br>
# M.Tech (Data Science and Engineering)<br> Data Visualization And Interpretation (DSECC ZG555))<br>
# Second Semester, 2022-23
# </center></h1>
#
# <h2><center>Assignment 2 – PS3 [Weightage 13%]</center></h2>

# %% [markdown]
# <ol>
#   <li>Do not change the name of the data file that is shared with the problem statement.</li>
#   <li>If intermediate data files are created, retain in the present working directory and attach them during submission.</li>
#   <li>Retain the data file in the same directory as that of this workbook.</li>
#   <li>Retain the Visualizations that is produced in the file. Don't clear them away.</li>
#      <li><div class="alert-warning">All the visuals should adhere to the visualization principles learnt in the Course and must be presentation ready.Most effective visuals would fetch maximum credits</div></li>
#     <li><div class="alert-warning">Submissions done via means other than CANVAS will strictly be NOT graded.</div></li>
# </ol>

# %% [markdown]
# <style>
# table {
#   font-family: arial, sans-serif;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 8px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
#
# <h2>Group No: (33)</h2>
#
# <table>
#   <tr>
#     <th>Full Name</th>
#     <th>BITS ID</th>
#     <th>Contribution</th>
#   </tr>
#   <tr>
#     <td>Mrutyunjay Shukla</td>
#     <td>2022c104060</td>
#     <td>100%</td>
#   </tr>
#   <tr>
#     <td>Debarati Banerjee</td>
#     <td>2022C104015</td>
#     <td>100%</td>
#   </tr>
#   <tr>
#     <td>Mala Sharma</td>
#     <td>2022C104026</td>
#     <td>100%</td>
#   </tr>
# </table>

# %% [markdown]
# <h3>Objective</h3>
# <h4>What are the features that have the most impact on the car price?</h4>

# %% [markdown]
# ##  Download and Prep the Data: 1 Mark

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
db = pd.read_csv(r"C:\Users\mruty\Downloads\dvi-a2-ps3-data.csv")

# %%
db
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
db.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
db.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
db.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# <h4> Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.<br>
# Write down your observations in a markdown cell below. <h4>

# %%
db[['bore','stroke' ,'compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# # Visualisation Questions - 2X5 = 10 Marks

# %% [markdown]
# ### Question 1
# <h4>What kind of a correlation exists between<br><br>
#     a."engine-size" and "price"<br><br>
#     b."highway-mpg" and "price"<br><br>
#     c."peak-rpm" and "price"<br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.You obseravtaion about the relationship. Which among engine-size, highway-mpg and peak-rpm is a potential predictor variable of price.<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ##  1.Ans
#
# ###  a.Ans
#
# #### Engine-size to price : We can see higlhy linearity in Scatter Plot, we can say if the engine size increases the price also increases.
# #### Highway-mpg to price : The Scatter Plot is non linear , and also observed that, as price increases the Miles per gallon is getting decreased.
# #### Peak-rpm to price : In this Scatter Plot , we can see that it is non-linear in nature, most of the cases, as price increases Peak-rpm decreases.
#
# ###  b.Ans
#
# #### Used Red colour to show the line
# #### Shape and size used for every plot is same i.e., (8,6)
#
# ### c.Ans
#
# #### It follows Gestalt law of similarity
# #### It follows Gestalt law of continution and Proximity

# %%
# Figure size 

sns.set(rc={'figure.figsize':(8,6)})

# %%
# a. Engine Size and Price correlation 

db[["engine-size","price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
# a. Engine Size and Price - scatter plot.

sns.regplot(x="engine-size", y="price", data=db,scatter_kws={"color": "black"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 53179.09504730389)

# %%
# b. "highway-mpg" and "price" correlation

db[["highway-mpg","price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
# b. "highway-mpg" and "price" - scatter plot

sns.regplot(x="highway-mpg", y="price", data=db,scatter_kws={"color": "black"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 48170.96769821523)

# %%
# c."peak-rpm" and "price" correlation

db[["peak-rpm","price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
# c. "peak-rpm" and "price" - scatter plot

sns.regplot(x="peak-rpm", y="price", data=db,scatter_kws={"color": "black"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# ### Question 2
# <h4> Use boxplots to visualise the relationship between<br><br>
#     a."body-style" and "price". <br><br>
#     b."engine-location" and "price" <br><br>
#     c."drive-wheels"and "price" <br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.Your observataion about the relationship .Which among engine-location ,body-style and drive-wheels is a potential predictor variable of price<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ##  2.Ans
#
# ###  a.Ans
#
# #### Body style to price : In visual we can see convertible and Hardtop models are Expensive.
# #### Enigine location to price : Front enigne car are cheaper than rear end
# #### Wheel drive to price : Rear wheel drive are expesnive than all wheel and front wheel drive
#
# ###  b.Ans
#
# #### color used are similar ( Shades of Grey)
# #### Shape and size used for every plot is same i.e., (8,6)
#
# ### c.Ans
#
# #### It follows Gestalt law of similarity
# #### It follows Gestalt law of continution and Proximity

# %%
# a. "body-style" and "price" - Box Plot

sns.boxplot(x="body-style", y="price", data=db,palette="Greys_r")
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
# a. "engine-location" and "price" - Box Plot

sns.boxplot(x="engine-location", y="price", data=db,palette="Greys_r")
# Out:
# <AxesSubplot:xlabel='engine-location', ylabel='price'>

# %%
# c. "drive-wheels" and "price" - Box Plot

sns.boxplot(x="drive-wheels", y="price", data=db,palette="Greys_r")
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# ### Question 3
# <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all continuous variables.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ## 3.Ans
#
# #### 1. There is much diffirence in Max and mean in the price and Milage of a cars.
# #### 2. Selected table instead of chart , as we get more insights in this.

# %%
#  Describing the variables 
# it show's a summary of statsitical analysis of all the int or float variables

db.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %% [markdown]
#   ### Question 4
#   <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all variables of type 'Object'.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ## 4.Ans
#
# #### 1. toyota producing more cars than other brands, there are more front wheel drive cars than 4-wd and rear wd in data set, the data consists of more sedan type cars.
# #### 2. Selected table instead of chart , as we get more insights in this.

# %%
# to include objects  in dataset
db.describe(include=["object"])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
db["drive-wheels"].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
db["aspiration"].value_counts().to_frame()
# Out:
#        aspiration
# std           165
# turbo          36

# %%
db["make"].value_counts().to_frame()
# Out:
#                make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# chevrolet         3
# jaguar            3
# alfa-romero       3
# renault           2
# isuzu             2
# mercury           1

# %%
db["num-of-doors"].value_counts().to_frame()
# Out:
#       num-of-doors
# four           115
# two             86

# %%
db["body-style"].value_counts().to_frame()
# Out:
#              body-style
# sedan                94
# hatchback            68
# wagon                25
# hardtop               8
# convertible           6

# %%
db["engine-location"].value_counts().to_frame()
# Out:
#        engine-location
# front              198
# rear                 3

# %%
db["engine-type"].value_counts().to_frame()
# Out:
#        engine-type
# ohc            145
# ohcf            15
# ohcv            13
# l               12
# dohc            12
# rotor            4

# %% [markdown]
# ### Question 5
# <h4> Use a single heat map to visualize the relationship between Body Style and Drive-wheel vs Price.</h4>
# <h4>Perform the data preprocessing required.<br>
#
# <p>The heatmap should plot  the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.</p>
#
# The plot should have labels for x axis and y axis<br>
# Write down your observations in a markdown cell below the visual</h4>
#
# 1.Mention the pre-attentive attributes used.(atleast 2)<br>
# 2.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ###  1.Ans
#
# #### color used are similar ( Shades of Grey)
# #### Shape and size used for every plot is same i.e., (8,6)
#
# ### 2.Ans
#
# #### It follows Gestalt law of similarity.
# #### It follows Gestalt law of continution and Proximity.

# %%
# grouping 


db_grouptest=db[['drive-wheels','body-style','price']]
grouped_test1=db_grouptest.groupby(['drive-wheels','body-style'],as_index= False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
# Finding Out Null Values if any

grouped_test1.info() # There are no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   drive-wheels  13 non-null     object
#  1   body-style    13 non-null     object
#  2   price         13 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 416.0+ bytes

# %%
# Pivots

grouped_pivot=grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
# HeatMap
plt.pcolor(grouped_pivot, cmap='gray_r')
plt.colorbar()
plt.show()

# %% [markdown]
# # Group's choice-2 Marks
#
# #### Frame 1 (more) question which will help in the EDA(Exploratory Data Analysis) of the given data set and answer the same using the best visual.
#
#  1. Write the question in a markdown cell
#  2. Below the question,in a coding cell,write the python code to create the visual to answer the question
#
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    2.The reason for selecting the chart type you did. <br>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ###  1.Ans
# #### Cars with high horse power  are expensinve
#
# ###  2.Ans
# #### By the use of box-plot we can find :  median , max , min easily and by heat we can find out correlation between variables given.
#
# ###  3.Ans
# #### color used are similar ( Shades of Grey)
# #### Shape and size used for  plot are  i.e., (8,6) and for heat map (20,10)
#
# ### 4.Ans
#
# #### It follows Gestalt law of similarity.
# #### It follows Gestalt law of continution and Proximity.

# %%
# "horsepower-binned" and "price" - Box Plot

sns.boxplot(x="horsepower-binned", y="price", data=db,palette="Greys_r")
# Out:
# <AxesSubplot:xlabel='horsepower-binned', ylabel='price'>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(db.corr(),annot=True,cmap='Greys_r')
plt.title("Correlation Of Each Numerical Features")
plt.show()

# %% [markdown]
# <h3><center>END OF ASSIGNMENT</center><h34>
